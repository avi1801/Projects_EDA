# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            background-color:yellow;
#            font-size:400%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="
#           padding: 20px;
#           color:black;
#           font-size:120%;
#           font-weight:bold;
#           line-height:1.5;
#           text-align:center;">
# SUPER MARKET EXPLORATORY DATA ANALYSIS
# </p>
# </div>

# %% [markdown]
# ![tomwerner-b96626d72d0341dfb14ca023e7895dfa.jpg](attachment:tomwerner-b96626d72d0341dfb14ca023e7895dfa.jpg)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            background-color:pink;
#            font-size:300%;
#            font-family:Serif;
#            letter-spacing:0.8px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           font-weight:bold;
#           line-height:1.5;
#           text-align:center;">
# OBJECTIVE
# </p>
# </div>

# %% [markdown]
# #### The growth of supermarkets in most populated cities are increasing and market competitions are also high. The dataset is one of the historical sales of supermarket company which has recorded in 3 different branches for 3 months data.
# #### Predictive data analytics methods are easy to apply with this dataset.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:10px;
#            background-color:pink;
#            font-size:250%;
#            font-family:Serif;
#            letter-spacing:0.8px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           font-weight:bold;
#           line-height:1.5;
#           text-align:center;">
# PROBLEM STATEMENTS
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Importing Required Libraries
# </p>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Loading the Data Set
# </p>
# </div>

# %%
df=pd.read_csv("C:\\Users\\Avishekh Kumar Gupta\\Downloads\\data sets-20230826T062735Z-001\\data sets\\supermarket_sales - Sheet1.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Basic Understanding of data
# </p>
# </div>

# %% [markdown]
# # How big is the Data?

# %%
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# ###  Observation: It has 1000 rows and 17 columns

# %% [markdown]
# #  Preview  of the Data

# %%
df.sample(2)
# Out:
#       Invoice ID Branch       City Customer type  Gender        Product line  \
# 429  325-77-6186      A     Yangon        Member  Female  Home and lifestyle
# 198  699-01-4164      C  Naypyitaw        Normal    Male   Health and beauty
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 429       90.65        10  45.325  951.825   3/8/2019  10:53      Ewallet
# 198       41.50         4   8.300  174.300  3/12/2019  19:58  Credit card
#
#       cogs  gross margin percentage  gross income  Rating
# 429  906.5                 4.761905        45.325     7.3
# 198  166.0                 4.761905         8.300     8.2

# %% [markdown]
# # Basic Information of the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# ### Observation:  From above ouput we can say that all the columns are of appropriate type only the column Date and Time need to be converted into Date time
# ### Out of 17 columns- dtypes: float(7 columns), int(1 columns), object(9 columns)

# %% [markdown]
# # Fetching Columns Names

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Pre-Processing The Data
# </p>
# </div>

# %% [markdown]
# # Checking The Missing Values

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# ### Data seems simple as there is no missing value in the data

# %% [markdown]
# # Checking Duplicacy

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### From above we can see there is no duplicacy in the Dataset

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# # Segregate the Object & Numeric Data Types

# %%
df_obj=df.select_dtypes(include="object")

# %%
df_obj
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line       Date   Time      Payment
# 0         Health and beauty   1/5/2019  13:08      Ewallet
# 1    Electronic accessories   3/8/2019  10:29         Cash
# 2        Home and lifestyle   3/3/2019  13:23  Credit card
# ...

# %%
for i in df_obj:
    if i!="Invoice ID":
        print(i,"-----------------",df_obj[i].unique(),"has",df_obj[i].nunique(),"\n\n")
# Out:
# Branch ----------------- ['A' 'C' 'B'] has 3
#
#
# City ----------------- ['Yangon' 'Naypyitaw' 'Mandalay'] has 3
#
#
# Customer type ----------------- ['Member' 'Normal'] has 2
#
#
# Gender ----------------- ['Female' 'Male'] has 2
#
#
# Product line ----------------- ['Health and beauty' 'Electronic accessories' 'Home and lifestyle'
#  'Sports and travel' 'Food and beverages' 'Fashion accessories'] has 6
#
#
# Date ----------------- ['1/5/2019' '3/8/2019' '3/3/2019' '1/27/2019' '2/8/2019' '3/25/2019'
#  '2/25/2019' '2/24/2019' '1/10/2019' '2/20/2019' '2/6/2019' '3/9/2019'
#  '2/12/2019' '2/7/2019' '3/29/2019' '1/15/2019' '3/11/2019' '1/1/2019'
#  '1/21/2019' '3/5/2019' '3/15/2019' '2/17/2019' '3/2/2019' '3/22/2019'
#  '3/10/2019' '1/25/2019' '1/28/2019' '1/7/2019' '3/23/2019' '1/17/2019'
#  '2/2/2019' '3/4/2019' '3/16/2019' '2/27/2019' '2/10/2019' '3/19/2019'
#  '2/3/2019' '3/7/2019' '2/28/2019' '3/27/2019' '1/20/2019' '3/12/2019'
# ...

# %% [markdown]
# ## Obeservation:-
# * The Branch column has 3 unique values(A,B,C)
# * The City column contains 3 unique values(Yangon,Naypyitaw,Mandalay)
# * Customer Type contains 2 unique values(Member, Normal)
# * Gender has 2 unique values(Male, Female)
# * Product Line contains 6 unique values ['Health and        beauty' 'Electronic accessories' 'Home and lifestyle'
#  'Sports and travel' 'Food and beverages' 'Fashion accessories']
#  * From the Date column we came to know that whole data is of one year(2019)
#  * Time is there showing the time of purchase
#  * Payment column is there showing the various methods by which payment is done, so there are 3 methods(Cash, Credit Card, Ewallet)

# %%
df_numeric=df.select_dtypes(exclude="object")

# %%
df_numeric.sample(2)
# Out:
#      Unit price  Quantity  Tax 5%    Total    cogs  gross margin percentage  \
# 130       39.62         7  13.867  291.207  277.34                 4.761905
# 134       81.30         6  24.390  512.190  487.80                 4.761905
#
#      gross income  Rating
# 130        13.867     7.5
# 134        24.390     5.3

# %%
df_numeric.columns
# Out:
# Index(['Unit price', 'Quantity', 'Tax 5%', 'Total', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
for i in df_numeric.columns:
    for j in df[i].unique():
        if ((j==0)|(j<0)):
            print("true")
else:
    print("no flaw in the columns")
# Out:
# no flaw in the columns

# %% [markdown]
# ### Observation:
# * There is no -ve, zero or not any flaw in the data set

# %% [markdown]
# # Columns Conversion

# %%
from datetime import datetime as dt

# %% [markdown]
# ## In the data set Date and Time columns were in object so we converted into Date Time

# %%
df["Date"]=pd.to_datetime(df["Date"])
df["Time"]=pd.to_datetime(df["Time"])

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                       datetime64[ns]
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %% [markdown]
# ## Here below we are extracting Month, Day, Week of the Day & Hours

# %%
df["Month"]=df.Date.dt.month_name()  ## extracting month 
df["day"]=df.Date.dt.day   # extracting day 
df["day_of_week"]=df.Date.dt.day_name()  # extracting week of the  day 
df["hour"]=df.Time.dt.hour # extracting hour

# %%
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  ...
# 1  Electronic accessories       15.28         5   3.8200   80.2200  ...
#
#                  Time  Payment    cogs  gross margin percentage  gross income  \
# 0 2023-12-19 13:08:00  Ewallet  522.83                 4.761905       26.1415
# 1 2023-12-19 10:29:00     Cash   76.40                 4.761905        3.8200
#
#    Rating    Month day  day_of_week hour
# 0     9.1  January   5     Saturday   13
# 1     9.6    March   8       Friday   10
#
# [2 rows x 21 columns]

# %% [markdown]
# # We are deleting the irrelavant columns
# * Invoice ID
# * City

# %%
df.drop(columns=["Invoice ID","City"],inplace=True)

# %% [markdown]
# # In the above we drop the columns Invoice ID as it is not relvent us and also City because in the data Branch is acting as city

# %%
df.shape
# Out:
# (1000, 19)

# %% [markdown]
# # Descriptive Stats

# %%
df.describe().T
# Out:
#                           count        mean           std        min  \
# Unit price               1000.0   55.672130  2.649463e+01  10.080000
# Quantity                 1000.0    5.510000  2.923431e+00   1.000000
# Tax 5%                   1000.0   15.379369  1.170883e+01   0.508500
# Total                    1000.0  322.966749  2.458853e+02  10.678500
# cogs                     1000.0  307.587380  2.341765e+02  10.170000
# gross margin percentage  1000.0    4.761905  6.220360e-14   4.761905
# gross income             1000.0   15.379369  1.170883e+01   0.508500
# Rating                   1000.0    6.972700  1.718580e+00   4.000000
# day                      1000.0   15.256000  8.693563e+00   1.000000
# hour                     1000.0   14.910000  3.186857e+00  10.000000
#
#                                 25%         50%         75%          max
# Unit price                32.875000   55.230000   77.935000    99.960000
# ...

# %%
df["gross margin percentage"].unique()
# Out:
# array([4.76190476])

# %%
columns=df.describe().T.index
columns
# Out:
# Index(['Unit price', 'Quantity', 'Tax 5%', 'Total', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating', 'day', 'hour'],
#       dtype='object')

# %%
columns=columns[0:-2]
columns
# Out:
# Index(['Unit price', 'Quantity', 'Tax 5%', 'Total', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
pos=1
plt.figure(figsize=(12,10))
for i in columns:
    plt.subplot(3,3,pos)
    plt.boxplot(df[i])
    plt.title(i)
    pos=pos+1

# %% [markdown]
# ### From the above graph we came to know that Total, Tax 5% & Cogs are having the same graph and the gross margin percentage is same through out the data
# ### We have Outliers in Tax 5%, Total, cogs, Gross income

# %% [markdown]
# # Now we check the Correlation

# %%
df[columns].corr()
# Out:
#                            Unit price      Quantity        Tax 5%  \
# Unit price               1.000000e+00  1.077756e-02  6.339621e-01
# Quantity                 1.077756e-02  1.000000e+00  7.055102e-01
# Tax 5%                   6.339621e-01  7.055102e-01  1.000000e+00
# Total                    6.339621e-01  7.055102e-01  1.000000e+00
# cogs                     6.339621e-01  7.055102e-01  1.000000e+00
# gross margin percentage -6.998957e-16 -3.849075e-16  2.461896e-16
# gross income             6.339621e-01  7.055102e-01  1.000000e+00
# Rating                  -8.777507e-03 -1.581490e-02 -3.644170e-02
#
#                                 Total          cogs  gross margin percentage  \
# Unit price               6.339621e-01  6.339621e-01            -6.998957e-16
# Quantity                 7.055102e-01  7.055102e-01            -3.849075e-16
# Tax 5%                   1.000000e+00  1.000000e+00             2.461896e-16
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df[columns].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Observation-: From the above HeatMap we came to know that
# * Gross Margin Percentage is same through out the data so
# * Total, Tax 5% & Cogs are having the same graph so the Coorelation value is coming 1
# * The relation between Quantity & Total tells that if the quantity gets increase then the total will also increase

# %%
df.columns
# Out:
# Index(['Branch', 'Customer type', 'Gender', 'Product line', 'Unit price',
#        'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating', 'Month', 'day',
#        'day_of_week', 'hour'],
#       dtype='object')

# %%
df.drop(columns=["cogs","gross margin percentage","Tax 5%"],inplace=True)

# %% [markdown]
# ### We have drop the tables Cogs, Gross Margin Percentage,Tax because from all 3 columns same info and we can consider the column Total for anaylsis point

# %%
df.head(2)
# Out:
#   Branch Customer type  Gender            Product line  Unit price  Quantity  \
# 0      A        Member  Female       Health and beauty       74.69         7
# 1      C        Normal  Female  Electronic accessories       15.28         5
#
#       Total       Date                Time  Payment  gross income  Rating  \
# 0  548.9715 2019-01-05 2023-12-19 13:08:00  Ewallet       26.1415     9.1
# 1   80.2200 2019-03-08 2023-12-19 10:29:00     Cash        3.8200     9.6
#
#      Month  day day_of_week  hour
# 0  January    5    Saturday    13
# 1    March    8      Friday    10

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:20px;
#            background-color:pink;
#            font-size:300%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 20px;
#           color:black;
#           font-size:120%;
#           font-weight:bold;
#           text-align:center;">
# INSIGHTS
# </p>
# </div>

# %% [markdown]
# # Total Sale of the Supermarket

# %%
df["Total"].sum()
# Out:
# 322966.74899999995

# %% [markdown]
# ### Obersevation:- Total Sale of the Supermarket 322966.74

# %% [markdown]
# # Total sale of each Branch

# %%
df.groupby(["Branch"])["Total"].sum()
# Out:
# Branch
# A    106200.3705
# B    106197.6720
# C    110568.7065
# Name: Total, dtype: float64

# %%
sns.catplot(x="Branch",y="Total",kind="bar",data=df,estimator=sum,palette="pastel")
plt.title("Hot Selling Branch",color="Red",fontsize=20,fontweight="bold")
plt.xlabel("Branch",fontsize=15, loc="center")
plt.ylabel("Total",fontsize=15, loc="center")
plt.grid(color="black",linestyle="dotted")

# %% [markdown]
# ### From above we came to now that there is not so much differnce in all the Branches but C is Hot Selling Branch

# %%
plt.figure(figsize=(15,5),facecolor="yellow")
plt.subplot(1,2,1)
sns.barplot(x="Branch",y="Total",data=df,estimator=sum,palette="pastel")
plt.xlabel("Branch",fontsize=15, loc="center")
plt.ylabel("Total",fontsize=15, loc="center")
plt.title("Total sale of each Branch",color="red",fontweight="bold",fontsize=20)
plt.subplot(1,2,2)
sns.barplot(x="Branch",y="Total",data=df,palette="pastel")
plt.xlabel("Branch",fontsize=15, loc="center")
plt.ylabel("Total",fontsize=15, loc="center")
plt.title("Average sale of each Branch",color="red",fontweight="bold",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Average sale of each Branch')

# %% [markdown]
# ## In the above plot two graphs showing:
# * Total sale in each Branch
# * Avg sale in each branch

# %%
df.head(2)
# Out:
#   Branch Customer type  Gender            Product line  Unit price  Quantity  \
# 0      A        Member  Female       Health and beauty       74.69         7
# 1      C        Normal  Female  Electronic accessories       15.28         5
#
#       Total       Date                Time  Payment  gross income  Rating  \
# 0  548.9715 2019-01-05 2023-12-19 13:08:00  Ewallet       26.1415     9.1
# 1   80.2200 2019-03-08 2023-12-19 10:29:00     Cash        3.8200     9.6
#
#      Month  day day_of_week  hour
# 0  January    5    Saturday    13
# 1    March    8      Friday    10

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Branch",data=df,hue="Customer type");

# %% [markdown]
# ### Since all the branches are having almost equal number of membership and non membership customers

# %%
df.head(2)
# Out:
#   Branch Customer type  Gender            Product line  Unit price  Quantity  \
# 0      A        Member  Female       Health and beauty       74.69         7
# 1      C        Normal  Female  Electronic accessories       15.28         5
#
#       Total       Date                Time  Payment  gross income  Rating  \
# 0  548.9715 2019-01-05 2023-12-19 13:08:00  Ewallet       26.1415     9.1
# 1   80.2200 2019-03-08 2023-12-19 10:29:00     Cash        3.8200     9.6
#
#      Month  day day_of_week  hour
# 0  January    5    Saturday    13
# 1    March    8      Friday    10

# %%
sns.barplot(x="Branch",y="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Rating'>

# %% [markdown]
# ### Checked the all Branch with respect to Rating but there is not much different in the all Branch

# %% [markdown]
# # Since C is found to be Hot Selling Branch so we find the maximum and min sale on any day

# %%
df_c=df[df["Branch"]=="C"]
df_c[df_c["Total"]==df_c["Total"].max()]
# Out:
#     Branch Customer type  Gender         Product line  Unit price  Quantity  \
# 350      C        Member  Female  Fashion accessories        99.3        10
#
#        Total       Date                Time      Payment  gross income  \
# 350  1042.65 2019-02-15 2023-12-19 14:53:00  Credit card         49.65
#
#      Rating     Month  day day_of_week  hour
# 350     6.6  February   15      Friday    14

# %% [markdown]
# ### From the above we came to know that max. sale in the Branch C i.e Hot Selling Branch and the product is from Fashion Accessories and was brought by Female  on the Date 15 Feb 2019(Friday) and the total was 1042.65

# %%
df_c[df_c["Total"]==df_c["Total"].min()].T.rename(columns={822:"values"})
# Out:
#                             values
# Branch                           C
# Customer type               Member
# Gender                        Male
# Product line     Sports and travel
# Unit price                   10.17
# Quantity                         1
# Total                      10.6785
# Date           2019-02-07 00:00:00
# Time           2023-12-19 14:15:00
# Payment                       Cash
# gross income                0.5085
# Rating                         5.9
# Month                     February
# day                              7
# day_of_week               Thursday
# hour                            14

# %% [markdown]
# ### In the above we came to know the min. sale in the Branch C and for better understanding  we transpose

# %%
df.head(2)
# Out:
#   Branch Customer type  Gender            Product line  Unit price  Quantity  \
# 0      A        Member  Female       Health and beauty       74.69         7
# 1      C        Normal  Female  Electronic accessories       15.28         5
#
#       Total       Date                Time  Payment  gross income  Rating  \
# 0  548.9715 2019-01-05 2023-12-19 13:08:00  Ewallet       26.1415     9.1
# 1   80.2200 2019-03-08 2023-12-19 10:29:00     Cash        3.8200     9.6
#
#      Month  day day_of_week  hour
# 0  January    5    Saturday    13
# 1    March    8      Friday    10

# %% [markdown]
# # Sale Trend of the Supermarket

# %%
sns.relplot(x="Date",y="Total",data=df,kind="line")
plt.xticks(rotation=90);

# %%
df.groupby(["Date"])["Total"].mean()
# Out:
# Date
# 2019-01-01    395.431750
# 2019-01-02    243.187875
# 2019-01-03    259.766062
# 2019-01-04    270.614750
# 2019-01-05    294.723625
#                  ...
# 2019-03-26    150.962538
# 2019-03-27    290.281950
# 2019-03-28    222.940200
# 2019-03-29    502.905375
# 2019-03-30    407.914500
# Name: Total, Length: 89, dtype: float64

# %% [markdown]
# # Sale Trend of each Branch

# %%
sns.relplot(x="Date",y="Total",data=df,kind="line",hue="Branch")
plt.xticks(rotation=90);

# %% [markdown]
# # Sale Trend of each Branch in Branch wise

# %%
plt.figure(figsize=(20,10),facecolor="yellow")
sns.relplot(x="Date",y="Total",data=df,kind="line",col="Branch")
plt.xticks(rotation=90);

# %%
df.groupby(["Branch", "Date"])[["Total"]].mean()
# Out:
#                        Total
# Branch Date
# A      2019-01-01  474.26400
#        2019-01-02  153.52575
#        2019-01-03  312.46950
#        2019-01-04  241.63125
#        2019-01-05  404.90100
# ...                      ...
# C      2019-03-26  118.49250
#        2019-03-27  943.29900
#        2019-03-28  160.26850
#        2019-03-29  492.84900
#        2019-03-30  360.49650
#
# [263 rows x 1 columns]

# %% [markdown]
# # Hot Selling Month over all data

# %%
df.columns
# Out:
# Index(['Branch', 'Customer type', 'Gender', 'Product line', 'Unit price',
#        'Quantity', 'Total', 'Date', 'Time', 'Payment', 'gross income',
#        'Rating', 'Month', 'day', 'day_of_week', 'hour'],
#       dtype='object')

# %%
sns.barplot(x="Month",y="Total",data=df,estimator=sum);

# %% [markdown]
# ### From the above we came to know that January was the Peak or Hot selling month for the company and we also came to that in the data set there is only 3 months data is present

# %% [markdown]
# # Hot selling month for each Branch

# %%
sns.barplot(x="Branch",y="Total",data=df,hue="Month",estimator=sum)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Total'>

# %% [markdown]
# ### From the above graph we came to know that Hot Selling month for all three Branch is January

# %%
df_c=df[df["Branch"]=="C"]
df_b=df[df["Branch"]=="B"]
df_a=df[df["Branch"]=="A"]

# %%
br=[df_c,df_b,df_a]
branch=["C","B","A"]
pos=1
plt.figure(figsize=(15,5),facecolor="yellow")
for i in br:
    plt.subplot(1,3,pos)
    sns.barplot(x="Month",y="Total",data=i,estimator=sum)
    plt.title(branch[pos-1],fontweight="bold",fontsize=15)
    pos=pos+1

# %% [markdown]
# ### From the above we came to know that January was the Peak or Hot selling month for the company

# %% [markdown]
# # Hot Selling Day for each Branch

# %%
df.columns
# Out:
# Index(['Branch', 'Customer type', 'Gender', 'Product line', 'Unit price',
#        'Quantity', 'Total', 'Date', 'Time', 'Payment', 'gross income',
#        'Rating', 'Month', 'day', 'day_of_week', 'hour'],
#       dtype='object')

# %%
br=[df_c,df_b,df_a]
branch=["C","B","A"]
pos=1
plt.figure(figsize=(15,10),facecolor="yellow")
for i in br:
    plt.subplot(3,1,pos)
    sns.barplot(x="day",y="Total",data=i,estimator=sum)
    plt.title(branch[pos-1],fontweight="bold")
    pos=pos+1
plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# ### From the above Graphs Branch C is having 23 day is a hot selling day
# ### From the above Graphs Branch B is having 15 day is a hot selling day
# ### From the above Graphs Branch A is having 19 day is a hot selling day

# %% [markdown]
# # Weekday or Weekend sale

# %%
df.head(2)
# Out:
#   Branch Customer type  Gender            Product line  Unit price  Quantity  \
# 0      A        Member  Female       Health and beauty       74.69         7
# 1      C        Normal  Female  Electronic accessories       15.28         5
#
#       Total       Date                Time  Payment  gross income  Rating  \
# 0  548.9715 2019-01-05 2023-12-19 13:08:00  Ewallet       26.1415     9.1
# 1   80.2200 2019-03-08 2023-12-19 10:29:00     Cash        3.8200     9.6
#
#      Month  day day_of_week  hour
# 0  January    5    Saturday    13
# 1    March    8      Friday    10

# %%
df["weekend/weekday"]=df["day_of_week"].apply(lambda x: "weekend" if ((x=="Saturday") | (x=="Sunday")) else "weekday")

# %% [markdown]
# ### We have added a new column in the data,taking "day_of_week" column we applied lambda function and if the day is Saturday or Sunday then it's Weekend else other days are Weekday and review of data & new column is below

# %%
df.head(2)
# Out:
#   Branch Customer type  Gender            Product line  Unit price  Quantity  \
# 0      A        Member  Female       Health and beauty       74.69         7
# 1      C        Normal  Female  Electronic accessories       15.28         5
#
#       Total       Date                Time  Payment  gross income  Rating  \
# 0  548.9715 2019-01-05 2023-12-19 13:08:00  Ewallet       26.1415     9.1
# 1   80.2200 2019-03-08 2023-12-19 10:29:00     Cash        3.8200     9.6
#
#      Month  day day_of_week  hour weekend/weekday
# 0  January    5    Saturday    13         weekend
# 1    March    8      Friday    10         weekday

# %%
df_c.head(2)
# Out:
#   Branch Customer type  Gender            Product line  Unit price  Quantity  \
# 1      C        Normal  Female  Electronic accessories       15.28         5
# 5      C        Normal    Male  Electronic accessories       85.39         7
#
#       Total       Date                Time  Payment  gross income  Rating  \
# 1   80.2200 2019-03-08 2023-12-19 10:29:00     Cash        3.8200     9.6
# 5  627.6165 2019-03-25 2023-12-19 18:30:00  Ewallet       29.8865     4.1
#
#    Month  day day_of_week  hour
# 1  March    8      Friday    10
# 5  March   25      Monday    18

# %%
df_c.columns
# Out:
# Index(['Branch', 'Customer type', 'Gender', 'Product line', 'Unit price',
#        'Quantity', 'Total', 'Date', 'Time', 'Payment', 'gross income',
#        'Rating', 'Month', 'day', 'day_of_week', 'hour'],
#       dtype='object')

# %%
df_c=df[df["Branch"]=="C"]
df_b=df[df["Branch"]=="B"]
df_a=df[df["Branch"]=="A"]

# %%
br=[df_c,df_b,df_a]
branch=["C","B","A"]
pos=1
plt.figure(figsize=(15,10),facecolor="yellow")
for i in br:
    plt.subplot(3,1,pos)
    sns.barplot(x="weekend/weekday",y="Total",data=i,estimator=sum,hue="Branch")
    plt.title(branch[pos-1],fontweight="bold")
    pos=pos+1

# %% [markdown]
# # Product

# %% [markdown]
# # Most Popular Product of the Company

# %%
sns.countplot(x="Product line",data=df)
plt.xlabel("Branch",fontsize=15, loc="center",fontweight="bold")
plt.ylabel("Total",fontsize=15, loc="center",fontweight="bold")
plt.title(" Most Popular Product of the Company",fontweight="bold",fontsize=20)
plt.xticks(rotation=90,fontweight="bold");

# %%
df["Product line"].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %% [markdown]
# ### From the above we came to know that Fashion Accessories is the Hot Selling Product of the company

# %% [markdown]
# # Which product gave the highest revenue

# %%
sns.barplot(x="Product line",y="Total",data=df,estimator=sum)
plt.xlabel("Product line",fontsize=15, loc="center",fontweight="bold")
plt.ylabel("Total",fontsize=15, loc="center",fontweight="bold")
plt.title("Highest Revenue Product",fontweight="bold",fontsize=20)
plt.xticks(rotation=90,fontweight="bold");

# %% [markdown]
# ### From the above Graph we came to know that Food & Beverages is giving the Highest Revenue among all the product

# %% [markdown]
# # Hot Selling Product of each Branch

# %%
br=[df_c,df_b,df_a]
branch=["C","B","A"]
pos=1
plt.figure(figsize=(10,15))
for i in br:
    plt.subplot(3,1,pos)
    sns.barplot(x="Product line",y="Total",data=i,estimator=sum)
    plt.title(f"Hot Selling Product of {branch[pos-1]}",fontweight="bold",fontsize=20)
    plt.xticks(rotation=90,fontweight="bold")
    plt.yticks(fontweight="bold")
    plt.xlabel("Total",fontweight="bold",fontsize=10)
    plt.ylabel("Product Line",fontweight="bold",fontsize=10)
    pos=pos+1
plt.subplots_adjust(hspace=1.5)

# %% [markdown]
# ### From the Above in the Branch A Food & Beverages products is most Selling product
# ### From the Above in the Branch B Sport & Travel products is Hot Selling Product
# ### From the Above in the Branch A, Home & Lifestyle products is Hot Selling Product

# %%
df.head(3)
# Out:
#   Branch Customer type  Gender            Product line  Unit price  Quantity  \
# 0      A        Member  Female       Health and beauty       74.69         7
# 1      C        Normal  Female  Electronic accessories       15.28         5
# 2      A        Normal    Male      Home and lifestyle       46.33         7
#
#       Total       Date                Time      Payment  gross income  Rating  \
# 0  548.9715 2019-01-05 2023-12-19 13:08:00      Ewallet       26.1415     9.1
# 1   80.2200 2019-03-08 2023-12-19 10:29:00         Cash        3.8200     9.6
# 2  340.5255 2019-03-03 2023-12-19 13:23:00  Credit card       16.2155     7.4
#
#      Month  day day_of_week  hour weekend/weekday
# 0  January    5    Saturday    13         weekend
# 1    March    8      Friday    10         weekday
# 2    March    3      Sunday    13         weekend

# %% [markdown]
# # Peak Hour of the Company

# %%
sns.countplot(x="hour",data=df)
plt.xlabel("Hour",fontweight="bold",fontsize=10)
plt.ylabel("count",fontweight="bold",fontsize=10);

# %% [markdown]
# ## From the above we came to know that Peak Hour of the Company is 7:00PM

# %% [markdown]
# # Branch wise Peak hours

# %%
br=[df_c,df_b,df_a]
branch=["C","B","A"]
pos=1
plt.figure(figsize=(10,15))
for i in br:
    plt.subplot(3,1,pos)
    sns.lineplot(x="hour",y="Total",data=i,)
    plt.title(f"Peak Hour {branch[pos-1]}",fontweight="bold",fontsize=20)
    plt.xlabel("Hour",fontweight="bold",fontsize=10)
    plt.ylabel("Total",fontweight="bold",fontsize=10)
    plt.xticks(rotation=90)
    pos=pos+1
plt.subplots_adjust(hspace=0.3)

# %% [markdown]
# ### From above the Peak Hour of Branch A is between 11:00 AM & 1:00 PM
# ### From above the Peak Hour of Branch B is between 2:00 PM & 5:00 PM
# ### From above the Peak Hour of Branch A is between 2:00 PM & 7:00 PM

# %% [markdown]
# # Branch wise Peak Hours with respect to Product line

# %%
br=[df_c,df_b,df_a]
branch=["C","B","A"]
pos=1
plt.figure(figsize=(10,15))
for i in br:
    plt.subplot(3,1,pos)
    sns.lineplot(x="hour",y="Total",data=i,hue="Product line",ci=None)
    plt.title(f"Product Sale in Peak Hour {branch[pos-1]}",fontweight="bold",fontsize=15)
    plt.xlabel("Hour",fontweight="bold",fontsize=10)
    plt.ylabel("Total",fontweight="bold",fontsize=10)
    plt.xticks(rotation=90)
    pos=pos+1
plt.subplots_adjust(hspace=0.3)

# %% [markdown]
# ### From above in Branch C peak Hour - Home & Lifestyle is at 4:00 PM, Sports and Travel at 6:00 PM, Electronic Accessories & Food and Beverages both at 8:00 PM & Sports and Travels is having downfall at 5:00 PM
# ### From above in Branch B peak Hour- Food and Beverages is at 11 am, Home & Lifestyle is at 5 pm, Health and Beauty is at 3 pm and ther is a downfall in Fashion Accessories at 4 pm
# ### From above in Branch A peak Hour- Sports and Travels is at 7 pm, Food and Beverages is at 11 am, there is a sudden increment in Home and Lifestyle at 8 pm and major downfall in Fashion Accessories

# %%
df.head(2)
# Out:
#   Branch Customer type  Gender            Product line  Unit price  Quantity  \
# 0      A        Member  Female       Health and beauty       74.69         7
# 1      C        Normal  Female  Electronic accessories       15.28         5
#
#       Total       Date                Time  Payment  gross income  Rating  \
# 0  548.9715 2019-01-05 2023-12-19 13:08:00  Ewallet       26.1415     9.1
# 1   80.2200 2019-03-08 2023-12-19 10:29:00     Cash        3.8200     9.6
#
#      Month  day day_of_week  hour weekend/weekday
# 0  January    5    Saturday    13         weekend
# 1    March    8      Friday    10         weekday

# %% [markdown]
# # Customer Type

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="Branch",y="Total",data=df,hue="Customer type")
plt.xlabel("Branch",fontweight="bold",fontsize=10)
plt.ylabel("Total",fontweight="bold",fontsize=10);

# %% [markdown]
# ### Recomendation:- From the above we can see that there is not much difference in Membership and number but we can say Branch A has more sale from Membership.
# ### So we can suggest the Manager of Branch A, try to convert normal customers to Membership by introducing the new offers

# %%
df.head(2)
# Out:
#   Branch Customer type  Gender            Product line  Unit price  Quantity  \
# 0      A        Member  Female       Health and beauty       74.69         7
# 1      C        Normal  Female  Electronic accessories       15.28         5
#
#       Total       Date                Time  Payment  gross income  Rating  \
# 0  548.9715 2019-01-05 2023-12-19 13:08:00  Ewallet       26.1415     9.1
# 1   80.2200 2019-03-08 2023-12-19 10:29:00     Cash        3.8200     9.6
#
#      Month  day day_of_week  hour weekend/weekday
# 0  January    5    Saturday    13         weekend
# 1    March    8      Friday    10         weekday

# %% [markdown]
# # Sale from Male or Female

# %%
sns.countplot(x="Gender",data=df);

# %% [markdown]
# ### From above both Male & Female are purchasing same

# %%
sns.barplot(x="Branch",y="Total",data=df,hue="Gender")
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Total'>

# %% [markdown]
# ### From the above, in all 3 braches Females are pruchasing things more than Males

# %%
br=[df_c,df_b,df_a]
branch=["C","B","A"]
pos=1
plt.figure(figsize=(10,15))
for i in br:
    plt.subplot(3,1,pos)
    sns.barplot(x="Gender",y="Total",data=i,hue="Product line",ci=None)
    plt.title(f"Product Purchased by Male or Female  {branch[pos-1]}",fontweight="bold",fontsize=15)
    plt.xlabel("Gender",fontweight="bold",fontsize=10)
    plt.ylabel("Total",fontweight="bold",fontsize=10)
    plt.xticks(rotation=90)
    pos=pos+1
plt.subplots_adjust(hspace=0.5)

# %% [markdown]
# ### From the above in Branch A:- Females are purchasing Home & Lifestyle whereas Males are purchasing Sports & Travels
# ### From the above in Branch B:- Females are purchasing Home & Lifestyle whereas Males are purchasing Health & Beauty
# ### From the above in Branch C:- Females are purchasing Food & Beverages whereas Males are Electronics & Accessories

# %%
df.head(2)
# Out:
#   Branch Customer type  Gender            Product line  Unit price  Quantity  \
# 0      A        Member  Female       Health and beauty       74.69         7
# 1      C        Normal  Female  Electronic accessories       15.28         5
#
#       Total       Date                Time  Payment  gross income  Rating  \
# 0  548.9715 2019-01-05 2023-12-19 13:08:00  Ewallet       26.1415     9.1
# 1   80.2200 2019-03-08 2023-12-19 10:29:00     Cash        3.8200     9.6
#
#      Month  day day_of_week  hour weekend/weekday
# 0  January    5    Saturday    13         weekend
# 1    March    8      Friday    10         weekday

# %% [markdown]
# # Payment

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Branch",data=df,hue="Payment");

# %% [markdown]
# ### From the above in Branch A most of the customer did the payment with Ewallet.
# ### From the above in Branch B most of the customer did the payment with Cash.
# ### From the above in Branch C most of the customer did the payment with Ewallet.

# %%
br=df["Payment"].value_counts()  
br
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
plt.pie(br,labels=br.index,autopct="%.2f%%",shadow="True", colors=["grey","yellow","hotpink"]);

# %% [markdown]
# ### From the above Pie Chart we came to know that Payment done by:-
# * Ewallet-34.50%
# * Cash-34.40%
# * Credit Card-31.10%

# %% [markdown]
# # Rating

# %%
df.head(2)
# Out:
#   Branch Customer type  Gender            Product line  Unit price  Quantity  \
# 0      A        Member  Female       Health and beauty       74.69         7
# 1      C        Normal  Female  Electronic accessories       15.28         5
#
#       Total       Date                Time  Payment  gross income  Rating  \
# 0  548.9715 2019-01-05 2023-12-19 13:08:00  Ewallet       26.1415     9.1
# 1   80.2200 2019-03-08 2023-12-19 10:29:00     Cash        3.8200     9.6
#
#      Month  day day_of_week  hour weekend/weekday
# 0  January    5    Saturday    13         weekend
# 1    March    8      Friday    10         weekday

# %%
df.groupby(["Branch"])["Rating"].agg(["max","min","mean"])
# Out:
#          max  min      mean
# Branch
# A       10.0  4.0  7.027059
# B       10.0  4.0  6.818072
# C       10.0  4.0  7.072866

# %%
br=[df_c,df_b,df_a]
branch=["C","B","A"]
pos=1
plt.figure(figsize=(10,15))
for i in br:
    plt.subplot(3,1,pos)
    sns.barplot(x="Branch",y="Rating",data=i,estimator=max,ci=None)
    plt.title(f"Rating in each Branch {branch[pos-1]}",fontweight="bold",fontsize=15)
    plt.xlabel("Branch",fontweight="bold",fontsize=10)
    plt.ylabel("Rating",fontweight="bold",fontsize=10)
    pos=pos+1
plt.subplots_adjust(hspace=0.3)

# %%
br=[df_c,df_b,df_a]
branch=["C","B","A"]
pos=1
plt.figure(figsize=(10,15))
for i in br:
    plt.subplot(3,1,pos)
    sns.barplot(x="Branch",y="Rating",data=i,estimator=min,ci=None)
    plt.title(f"Rating in each Branch {branch[pos-1]}",fontweight="bold",fontsize=15)
    plt.xlabel("Branch",fontweight="bold",fontsize=10)
    plt.ylabel("Rating",fontweight="bold",fontsize=10)
    pos=pos+1
plt.subplots_adjust(hspace=0.3)

# %%
br=[df_c,df_b,df_a]
branch=["C","B","A"]
pos=1
plt.figure(figsize=(10,15))
for i in br:
    plt.subplot(3,1,pos)
    sns.barplot(x="Branch",y="Rating",data=i, hue="Gender",estimator=min,ci=None)
    plt.title(f"Rating in each Branch {branch[pos-1]}",fontweight="bold",fontsize=15)
    plt.xlabel("Branch",fontweight="bold",fontsize=10)
    plt.ylabel("Rating",fontweight="bold",fontsize=10)
    pos=pos+1
plt.subplots_adjust(hspace=0.3)

# %%
len(df_a[df_a["Rating"]==df_a["Rating"].max()])
# Out:
# 1

# %% [markdown]
# ### So in Branch A:- only 1 customer has given max. Rating

# %%
len(df_b[df_b["Rating"]==df_b["Rating"].max()])
# Out:
# 3

# %% [markdown]
# ### So in Branch B:- only 3 customer has given max. Rating

# %%
len(df_c[df_c["Rating"]==df_c["Rating"].max()])
# Out:
# 1

# %% [markdown]
# ### So in Branch C:- only 1 customer has given max. Rating

# %%
len(df_a[df_a["Rating"]==df_a["Rating"].min()])
# Out:
# 2

# %% [markdown]
# ### So in Branch A:- 2 customers has given min. Rating

# %%
len([df_b["Rating"]==df_b["Rating"].min()])
# Out:
# 1

# %% [markdown]
# ### So in Branch B:- only 1 customer has given min. Rating

# %%
len([df_c["Rating"]==df_c["Rating"].min()])
# Out:
# 1

# %% [markdown]
# ### So in Branch A:- only 1 customer has given min. Rating

# %%
len([df_c["Rating"]==df_c["Rating"].mean()])
# Out:
# 1

# %%
len([df_a["Rating"]==df_a["Rating"].mean()])
# Out:
# 1

# %%
len([df_b["Rating"]==df_b["Rating"].mean()])
# Out:
# 1

# %%
len(df_a[df_a["Rating"]==df_a["Rating"].min()])*100/len(df_a)
# Out:
# 0.5882352941176471

# %%
len(df_a[df_a["Rating"]==df_a["Rating"].max()])*100/len(df_a)
# Out:
# 0.29411764705882354

# %%
len(df_a[df_a["Rating"]<df_a["Rating"].mean()])*100/len(df_a)
# Out:
# 49.411764705882355

# %%
len(df_a[df_a["Rating"]>df_a["Rating"].mean()])*100/len(df_a)
# Out:
# 50.588235294117645

# %% [markdown]
# ### In Branch A 49.411% of customers rated below the mean of Branch A
# ### In Branch A 50.588% of customers rated above the mean of Branch A

# %%
len(df_b[df_b["Rating"]>df_b["Rating"].mean()])*100/len(df_b)
# Out:
# 46.98795180722892

# %%
len(df_b[df_b["Rating"]<df_b["Rating"].mean()])*100/len(df_b)
# Out:
# 53.01204819277108

# %% [markdown]
# ### In Branch B 46.987% of customers rated above the mean of Branch B
# ### In Branch A 53.012% of customers rated below the mean of Branch B

# %% [markdown]
# # Product Wise Rating :

# %%
sns.barplot(x="Product line",y="Rating",data=i,estimator=max,ci=None)
plt.xticks(rotation=90,fontweight="bold",fontsize=10)
plt.xlabel("Product Line",fontweight="bold",fontsize=15)
plt.ylabel("Rating",fontweight="bold",fontsize=15)
# Out:
# Text(0, 0.5, 'Rating')

# %%
sns.barplot(x="Product line",y="Rating",data=i,estimator=min,ci=None)
plt.xticks(rotation=90,fontweight="bold",fontsize=10)
plt.xlabel("Product Line",fontweight="bold",fontsize=15)
plt.ylabel("Rating",fontweight="bold",fontsize=15)
# Out:
# Text(0, 0.5, 'Rating')

# %%
df.groupby(["Branch"])["Rating"].agg(["max","min","mean"])
# Out:
#          max  min      mean
# Branch
# A       10.0  4.0  7.027059
# B       10.0  4.0  6.818072
# C       10.0  4.0  7.072866

# %% [markdown]
# ### Branch A max. Rating is 10, min Rating is 4, Mean is 7.027
# ### Branch B max. Rating is 10, min Rating is 4, Mean is 6.818
# ### Branch C max. Rating is 10, min Rating is 4, Mean is 7.072

# %%
df.groupby(["Product line"])["Rating"].agg(["max","min","mean"])
# Out:
#                          max  min      mean
# Product line
# Electronic accessories  10.0  4.0  6.924706
# Fashion accessories      9.9  4.0  7.029213
# Food and beverages       9.9  4.0  7.113218
# Health and beauty       10.0  4.0  7.003289
# Home and lifestyle       9.9  4.1  6.837500
# Sports and travel       10.0  4.0  6.916265

# %% [markdown]
# ### Electronic accessories	max rating is 10.0, min rating is 4.0, mean rating 6.924706
# ### Fashion accessories max rating is 9.9, min rating is 4.0, , mean rating 7.029213
# ### Food and beverages max rating is 9.9, min rating is 4.0, , mean rating 7.113218
# ### Health and beauty	max rating is 10.0, min rating is 4, mean rating 7.003289
# ### Home and lifestyle	max rating is 9.9, min rating is 4.1, , mean rating 6.837500
# ### Sports and travel	max rating is 10.0, min rating is 4.0, , mean rating 69.16265
